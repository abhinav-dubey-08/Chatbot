# %%
import json
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud,STOPWORDS
import missingno as msno

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
import keras
from keras.models import Sequential 
from keras.layers import Dense,Embedding,LSTM,Dropout
from keras.callbacks import ReduceLROnPlateau

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
import nltk
from nltk import word_tokenize
from nltk.stem import PorterStemmer

# %%
import torch
from typing import TypeGuard
from torch.utils.data import Dataset
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from transformers import pipeline
from transformers import DistilBertTokenizerFast
from transformers import BertForSequenceClassification,BertTokenizerFast
from transformers import TFDistilBertForSequenceClassification,TFTrainingArguments
from transformers import BertTokenizer,TFBertForSequenceClassification,BertConfig
from transformers import TrainingArguments,Trainer
# Out:
# C:\Users\abhin\anaconda3\Lib\site-packages\torch\utils\_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(
# WARNING:tensorflow:From C:\Users\abhin\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def load_json_file(file):
    with open(file,encoding='utf-8') as f:
        file_name = json.load(f)
    return file_name

file = "intents.json"
intents = load_json_file(file)

# %%
def creating_df():
    df = pd.DataFrame({
         'Pattern' : [],
         'Tag' : []
    })
    return df

df = creating_df()
df
# Out:
# Empty DataFrame
# Columns: [Pattern, Tag]
# Index: []

# %%
def extract_json_file(json_file,df):
    for intent in json_file['intents']:
        for pattern in intent['patterns']:
            sentence_tag = [pattern,intent['tag']]
            df.loc[len(df.index)] = sentence_tag
    return df

df = extract_json_file(intents,df)
df.head()
# Out:
#             Pattern       Tag
# 0          Hi there  greeting
# 1       How are you  greeting
# 2  Is anyone there?  greeting
# 3               Hey  greeting
# 4              Hola  greeting

# %%
df_2 = df.copy()
df_2.head()
# Out:
#             Pattern       Tag
# 0          Hi there  greeting
# 1       How are you  greeting
# 2  Is anyone there?  greeting
# 3               Hey  greeting
# 4              Hola  greeting

# %%
def print_shape_df(df,ds_name="df"):
    print(f"{ds_name} dataset has {df.shape[0]} rows and {df.shape[1]} columns")

print_shape_df(df,"Chatbot")
# Out:
# Chatbot dataset has 910 rows and 2 columns

# %%
def print_dfInfo(df, ds_name="df"):
    print(f"The info of {ds_name} dataset\n")
    print(df.info())

print_dfInfo(df,"Chatbot")
# Out:
# The info of Chatbot dataset
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 910 entries, 0 to 909
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Pattern  910 non-null    object
#  1   Tag      910 non-null    object
# dtypes: object(2)
# memory usage: 21.3+ KB
# None

# %%
def num_classes(df,target_col,ds_name="df"):
    print(f"The {ds_name} dataset has {len(df[target_col].unique())} classes")

num_classes(df,'Tag', 'Chatbot')
# Out:
# The Chatbot dataset has 255 classes

# %%
def check_null(df,ds_name="df"):
    print(f"Null Values in each col in the {ds_name} dataset:\n")
    print(df.isnull().sum())

check_null(df,"Chatbot")
# Out:
# Null Values in each col in the Chatbot dataset:
#
# Pattern    0
# Tag        0
# dtype: int64

# %%
def plot_miss_vals(df,ds_name="df"):
    msno.matrix(df)
    plt.title(f"Distribution of Missing Values in {ds_name} dataset",fontsie=30,fontstyle='oblique')
    plt.show()

plot_miss_vals(df,"Chatbot")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 6
#       3     plt.title(f"Distribution of Missing Values in {ds_name} dataset",fontsie=30,fontstyle='oblique')
#       4     plt.show()
# ----> 6 plot_miss_vals(df,"Chatbot")
#
# Cell In[14], line 3, in plot_miss_vals(df, ds_name)
#       1 def plot_miss_vals(df,ds_name="df"):
#       2     msno.matrix(df)
# ----> 3     plt.title(f"Distribution of Missing Values in {ds_name} dataset",fontsie=30,fontstyle='oblique')
#       4     plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:4125, in title(label, fontdict, loc, pad, y, **kwargs)
#    4115 @_copy_docstring_and_deprecators(Axes.set_title)
#    4116 def title(
#    4117     label: str,
#    (...)
#    4123     **kwargs,
#    4124 ) -> Text:
# -> 4125     return gca().set_title(label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:187, in Axes.set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     185 if fontdict is not None:
#     186     title.update(fontdict)
# --> 187 title._internal_update(kwargs)
#     188 return title
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: Text.set() got an unexpected keyword argument 'fontsie'

# %%
stemmer = PorterStemmer()
ignore_words=['?','!',',','.']

def preprocess_pattern(pattern):
    words=word_tokenize(pattern.lower())
    stemmed_words = [stemmer.stem(word) for word in words if word not in ignore_words]
    return " ".join(stemmed_words)

df['Pattern'] = df['Pattern'].apply(preprocess_pattern)

# %%
df.head()
# Out:
#           Pattern       Tag
# 0        hi there  greeting
# 1     how are you  greeting
# 2  is anyon there  greeting
# 3             hey  greeting
# 4            hola  greeting

# %%
print(df['Pattern'].isnull().sum())
# Out:
# 0

# %%
plt.figure(figsize=(20,20))
wc = WordCloud(max_words=2000,width=1600,height=800,stopwords=STOPWORDS).generate(' '.join(df['Pattern']))
plt.imshow(wc,interpolation='bilinear')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Visualize top words
def get_corpus(series):
    words = []
    for text in series:
        for word in text.split():
            words.append(word.strip())
    return words

corpus = get_corpus(df.Pattern)
corpus[:5]
# Out:
# ['hi', 'there', 'how', 'are', 'you']

# %%
print(f"dataset contains {len(corpus)} words")
# Out:
# dataset contains 5525 words

# %%
from collections import Counter
counter = Counter(corpus)
most_common = counter.most_common(10)
most_common = dict(most_common)
most_common
# Out:
# {'what': 293,
#  'learn': 261,
#  'of': 259,
#  'the': 221,
#  'is': 179,
#  'you': 133,
#  'in': 128,
#  'are': 118,
#  'algorithm': 115,
#  'machin': 107}

# %%
#Data Preprocessing
df_2.head()
# Out:
#             Pattern       Tag
# 0          Hi there  greeting
# 1       How are you  greeting
# 2  Is anyone there?  greeting
# 3               Hey  greeting
# 4              Hola  greeting

# %%
labels = df_2['Tag'].unique().tolist()
labels = [s.strip() for s in labels]
labels
# Out:
# ['greeting',
#  'goodbye',
#  'thanks',
#  'options',
#  'adverse_drug',
#  'blood_pressure',
#  'blood_pressure_search',
#  'pharmacy_search',
#  'hospital_search',
#  'Concern',
#  'Appreciation',
#  'Please',
#  'Criticism',
#  'Personal',
#  'LifeQueries',
#  'diff_classreg',
#  'traintest',
#  'Ensemble',
#  'LowBi_HighVar',
#  'diff_RF_GB',
#  'Neural_Network',
#  'Deep_Learning',
#  'diff_DPDPDW',
#  'building_a_model',
#  'choose_algo',
#  'BiasML',
#  'Variance',
#  'ML_DL',
#  'Prec_Rec',
#  'Para',
#  'SupLearn',
#  'types_SL',
#  'Classification_algo',
#  'ClassDef',
#  'Eg_Class',
#  'Reg',
#  'Reg_Eg',
#  'Class_Tasks',
#  'BinaryClass',
#  'distributionBC',
#  'pop_algo',
#  'MCC',
#  'distrbutionMC',
#  'Pop_algoMC',
#  'MLC',
#  'imbalanced_classification',
#  'use_reg',
#  'types_reg',
#  'func_SL',
#  'standard_approach',
#  'classifier',
#  'SVM',
#  'meth_SVM',
#  'Confusion_Matrix',
#  'Exp_TP_TN_FP_FN',
#  'ml',
#  'difference between Data Mining and Machine learning',
#  'Overfitting',
#  'Why overfitting happens',
#  'avoid overfitting',
#  'inductive machine learning',
#  'algorithms of Machine Learning',
#  'Algorithm techniques in Machine Learning',
#  'algorithm independent machine learning',
#  'difference between artificial learning and machine learning',
#  'classifier in machine learning',
#  'Model Selection in Machine Learning',
#  'various approaches for machine learning',
#  'dimension reduction in machine learning',
#  'Inductive Logic Programming in Machine Learning',
#  'unsupervised learning',
#  'example of unsupervised learning algorithm',
#  'use of unsupervised learning',
#  'types of unsupervised learning',
#  'different types of Learning/ Training models in ML',
#  'differences between supervised and unsupervised machine learning',
#  'differences between KNN and K-means clustering',
#  'unsupervised learning algorithms',
#  'applications of unsupervised machine learning',
#  'disadvantages of unsupervised machine learning',
#  'clustering',
#  'association',
#  'differences between K-Means and Hierarchical clustering',
#  'Hierarchical clustering',
#  'K-Means clustering',
#  'agglomerative clustering',
#  'dendrogram',
#  'K-Nearest Neighbors',
#  'clustering methods',
#  'unsupervised learning work',
#  'need of clustering',
#  'good clustering',
#  'major clustering techniques',
#  'examples of clustering applications',
#  'key difference between supervised and unsupervised learning',
#  'applications',
#  'working of GMaps',
#  'Friend Tag suggestion',
#  'Terms',
#  'ETA Prediction',
#  'Role of machine learning in voice assistants',
#  'Machine Learning in self-driving cars',
#  'Market Analysis',
#  'A/B Testing',
#  'Sampling',
#  'Dimensionality Reduction',
#  'Realtional Evaluation',
#  'Areas of Problems',
#  'PAC Learning',
#  'Sequence Learning process',
#  'gf_sp',
#  'gf_sp_again',
#  'creation_sp',
#  'ava_sp',
#  'smart_sp',
#  'evil_sp',
#  'hurt_sp',
#  'obey_sp',
#  'save_yourself_sp',
#  'sanjoy_sp',
#  'sing_happy_birthday_sp',
#  'sing_song_sp',
#  'book_sp',
#  'mark_sp',
#  'gandhi_sp',
#  'country_sp',
#  'human_sp',
#  'love_sp',
#  'will_love_sp',
#  'past_sp',
#  'sad_sp',
#  'fail_sp',
#  'kernel SVM',
#  'Recommended Systems',
#  'Overfitting in laymen term',
#  'Underfitting in laymen term',
#  'Curse of dimensionality',
#  'data normalization',
#  'clustering in short',
#  'EDA',
#  'avoid Bias',
#  'Z Score',
#  'odds ratio',
#  'classification problems',
#  'trade-off between accuracy and interpretability',
#  'missing data',
#  'gradient descent methods converge',
#  'methods of moments',
#  'Face Clustering Pipeline',
#  'working of unsupervised face clustering pipeline',
#  'python3 modules to implement unsupervised face clustering pipeline',
#  'face clustering and its realtion  unsupervised learning',
#  'exclusive clustering',
#  'overlapping clustering',
#  'probabilistic clustering',
#  'Fzzy c-Means',
#  'FCM algorithm',
#  'comparison between K-Means and FCM clustering',
#  'applications of association rules',
#  'terms related to association rules',
#  'algorithms for association rule generation',
#  'FP growth algorithm',
#  'FP tree structure by Han',
#  'algorithm for building a fp tree',
#  'algorithm for mining a fp tree',
#  'Apriori algorithm',
#  'working of apriori algorithm',
#  'limitations of apriori algorithm',
#  'ECLAT algorithm',
#  'working of eclat algorithm',
#  'advanatges of eclat algorithm',
#  'detection of fake users using unsupervised learning',
#  'reinforcement learning',
#  'relation between reinforcement learning and machine learning',
#  'key terms realted to reinforcement learning',
#  'formulation of a reinforcement problem',
#  'reinforcement learning algorithms',
#  'applications of reinforcement learning',
#  'resources to learn reinforcement learning',
#  'types of reinforcement learning',
#  'advantages and disadvanatages of reinforcement learning',
#  'why rl is hard',
#  'solution of cartpole problem',
#  "'action' in reinforcement learning",
#  "'agent' in reinforcement learning",
#  "'value' in reinforcement learning",
#  'q-value or action-value',
#  'value-based learning',
#  'policy-based reinforcement learning',
#  'model-based learning',
#  'PATTERN RECOGNITION',
#  'genetic programming',
#  'Inductive Logic Programming',
#  'model selection',
#  'calibration in Supervised Learning',
#  'overfitting',
#  'difference between heuristic for rule learning and heuristics',
#  'Perceptron',
#  'components of Bayesian logic program',
#  'bayesian networks',
#  'Lazy learning algorithm',
#  'Support Vector Machine',
#  'cross-validation?',
#  'ensemble learning?',
#  'basic data structures',
#  'Types of machine learning',
#  'Hypothesis Generation',
#  'Data Wrangling',
#  'labeled and unlabeled data',
#  'features and labels',
#  'Noise',
#  'imbalanced datasheet',
#  'Linear Discriminant Analysis',
#  'Gradient Descent',
#  'Regularization',
#  'Regularization in Machine Learning',
#  'Classification model',
#  'issues to consider in supervised learning',
#  'algorithm is used best for supervised learning',
#  'standard supervised learning',
#  'applications of supervised learning',
#  'Support Vector Machine',
#  'advantages of supervised learning',
#  'disadvantages of supervised learning',
#  'Decision Trees',
#  'K-Nearest Neighbor Algorithm',
#  'neural networks algorithms',
#  'algorithms used by neural networks.',
#  'best practices for supervised learning',
#  'self supervised learning',
#  'applications of self-supervised learning',
#  'Polynomial Regression',
#  'using Polynomial Regression',
#  'advantages of using Polynomial Regression over Linear Regression',
#  'Ridge Regression technique',
#  'importance of unsupervised learning',
#  'principle of Unsupervised Data Augmentation',
#  'use of auto encoder',
#  'PCA or auto encoder',
#  'use of unsupervised clustering models',
#  'techniques for anomaly detection on a dataset',
#  'need of unsupervised learning',
#  'unsupervised learning algorithm for categorical data',
#  'types of clustering methods',
#  'Density based lagorithms',
#  'hierarchical clustering based method',
#  'partitioning clustering method',
#  'grid-based clsutering methods',
#  'use of KNN algorithm',
#  'working of knn algorithm',
#  'disadvantages of knn algorithm',
#  'working of k-means algorithm',
#  'advantages of k-means algorithm',
#  'disadvantges of using k-means',
#  'advantages of knn algorithm']

# %%
num_labels = len(labels)
id2label = {id: label for id, label in enumerate(labels)}
label2id = {label: id for id, label in enumerate(labels)}

# %%
id2label
# Out:
# {0: 'greeting',
#  1: 'goodbye',
#  2: 'thanks',
#  3: 'options',
#  4: 'adverse_drug',
#  5: 'blood_pressure',
#  6: 'blood_pressure_search',
#  7: 'pharmacy_search',
#  8: 'hospital_search',
#  9: 'Concern',
#  10: 'Appreciation',
#  11: 'Please',
#  12: 'Criticism',
#  13: 'Personal',
#  14: 'LifeQueries',
#  15: 'diff_classreg',
#  16: 'traintest',
#  17: 'Ensemble',
#  18: 'LowBi_HighVar',
#  19: 'diff_RF_GB',
#  20: 'Neural_Network',
#  21: 'Deep_Learning',
#  22: 'diff_DPDPDW',
#  23: 'building_a_model',
#  24: 'choose_algo',
#  25: 'BiasML',
#  26: 'Variance',
#  27: 'ML_DL',
#  28: 'Prec_Rec',
#  29: 'Para',
#  30: 'SupLearn',
#  31: 'types_SL',
#  32: 'Classification_algo',
#  33: 'ClassDef',
#  34: 'Eg_Class',
#  35: 'Reg',
#  36: 'Reg_Eg',
#  37: 'Class_Tasks',
#  38: 'BinaryClass',
#  39: 'distributionBC',
#  40: 'pop_algo',
#  41: 'MCC',
#  42: 'distrbutionMC',
#  43: 'Pop_algoMC',
#  44: 'MLC',
#  45: 'imbalanced_classification',
#  46: 'use_reg',
#  47: 'types_reg',
#  48: 'func_SL',
#  49: 'standard_approach',
#  50: 'classifier',
#  51: 'SVM',
#  52: 'meth_SVM',
#  53: 'Confusion_Matrix',
#  54: 'Exp_TP_TN_FP_FN',
#  55: 'ml',
#  56: 'difference between Data Mining and Machine learning',
#  57: 'Overfitting',
#  58: 'Why overfitting happens',
#  59: 'avoid overfitting',
#  60: 'inductive machine learning',
#  61: 'algorithms of Machine Learning',
#  62: 'Algorithm techniques in Machine Learning',
#  63: 'algorithm independent machine learning',
#  64: 'difference between artificial learning and machine learning',
#  65: 'classifier in machine learning',
#  66: 'Model Selection in Machine Learning',
#  67: 'various approaches for machine learning',
#  68: 'dimension reduction in machine learning',
#  69: 'Inductive Logic Programming in Machine Learning',
#  70: 'unsupervised learning',
#  71: 'example of unsupervised learning algorithm',
#  72: 'use of unsupervised learning',
#  73: 'types of unsupervised learning',
#  74: 'different types of Learning/ Training models in ML',
#  75: 'differences between supervised and unsupervised machine learning',
#  76: 'differences between KNN and K-means clustering',
#  77: 'unsupervised learning algorithms',
#  78: 'applications of unsupervised machine learning',
#  79: 'disadvantages of unsupervised machine learning',
#  80: 'clustering',
#  81: 'association',
#  82: 'differences between K-Means and Hierarchical clustering',
#  83: 'Hierarchical clustering',
#  84: 'K-Means clustering',
#  85: 'agglomerative clustering',
#  86: 'dendrogram',
#  87: 'K-Nearest Neighbors',
#  88: 'clustering methods',
#  89: 'unsupervised learning work',
#  90: 'need of clustering',
#  91: 'good clustering',
#  92: 'major clustering techniques',
#  93: 'examples of clustering applications',
#  94: 'key difference between supervised and unsupervised learning',
#  95: 'applications',
#  96: 'working of GMaps',
#  97: 'Friend Tag suggestion',
#  98: 'Terms',
#  99: 'ETA Prediction',
#  100: 'Role of machine learning in voice assistants',
#  101: 'Machine Learning in self-driving cars',
#  102: 'Market Analysis',
#  103: 'A/B Testing',
#  104: 'Sampling',
#  105: 'Dimensionality Reduction',
#  106: 'Realtional Evaluation',
#  107: 'Areas of Problems',
#  108: 'PAC Learning',
#  109: 'Sequence Learning process',
#  110: 'gf_sp',
#  111: 'gf_sp_again',
#  112: 'creation_sp',
#  113: 'ava_sp',
#  114: 'smart_sp',
#  115: 'evil_sp',
#  116: 'hurt_sp',
#  117: 'obey_sp',
#  118: 'save_yourself_sp',
#  119: 'sanjoy_sp',
#  120: 'sing_happy_birthday_sp',
#  121: 'sing_song_sp',
#  122: 'book_sp',
#  123: 'mark_sp',
#  124: 'gandhi_sp',
#  125: 'country_sp',
#  126: 'human_sp',
#  127: 'love_sp',
#  128: 'will_love_sp',
#  129: 'past_sp',
#  130: 'sad_sp',
#  131: 'fail_sp',
#  132: 'kernel SVM',
#  133: 'Recommended Systems',
#  134: 'Overfitting in laymen term',
#  135: 'Underfitting in laymen term',
#  136: 'Curse of dimensionality',
#  137: 'data normalization',
#  138: 'clustering in short',
#  139: 'EDA',
#  140: 'avoid Bias',
#  141: 'Z Score',
#  142: 'odds ratio',
#  143: 'classification problems',
#  144: 'trade-off between accuracy and interpretability',
#  145: 'missing data',
#  146: 'gradient descent methods converge',
#  147: 'methods of moments',
#  148: 'Face Clustering Pipeline',
#  149: 'working of unsupervised face clustering pipeline',
#  150: 'python3 modules to implement unsupervised face clustering pipeline',
#  151: 'face clustering and its realtion  unsupervised learning',
#  152: 'exclusive clustering',
#  153: 'overlapping clustering',
#  154: 'probabilistic clustering',
#  155: 'Fzzy c-Means',
#  156: 'FCM algorithm',
#  157: 'comparison between K-Means and FCM clustering',
#  158: 'applications of association rules',
#  159: 'terms related to association rules',
#  160: 'algorithms for association rule generation',
#  161: 'FP growth algorithm',
#  162: 'FP tree structure by Han',
#  163: 'algorithm for building a fp tree',
#  164: 'algorithm for mining a fp tree',
#  165: 'Apriori algorithm',
#  166: 'working of apriori algorithm',
#  167: 'limitations of apriori algorithm',
#  168: 'ECLAT algorithm',
#  169: 'working of eclat algorithm',
#  170: 'advanatges of eclat algorithm',
#  171: 'detection of fake users using unsupervised learning',
#  172: 'reinforcement learning',
#  173: 'relation between reinforcement learning and machine learning',
#  174: 'key terms realted to reinforcement learning',
#  175: 'formulation of a reinforcement problem',
#  176: 'reinforcement learning algorithms',
#  177: 'applications of reinforcement learning',
#  178: 'resources to learn reinforcement learning',
#  179: 'types of reinforcement learning',
#  180: 'advantages and disadvanatages of reinforcement learning',
#  181: 'why rl is hard',
#  182: 'solution of cartpole problem',
#  183: "'action' in reinforcement learning",
#  184: "'agent' in reinforcement learning",
#  185: "'value' in reinforcement learning",
#  186: 'q-value or action-value',
#  187: 'value-based learning',
#  188: 'policy-based reinforcement learning',
#  189: 'model-based learning',
#  190: 'PATTERN RECOGNITION',
#  191: 'genetic programming',
#  192: 'Inductive Logic Programming',
#  193: 'model selection',
#  194: 'calibration in Supervised Learning',
#  195: 'overfitting',
#  196: 'difference between heuristic for rule learning and heuristics',
#  197: 'Perceptron',
#  198: 'components of Bayesian logic program',
#  199: 'bayesian networks',
#  200: 'Lazy learning algorithm',
#  201: 'Support Vector Machine',
#  202: 'cross-validation?',
#  203: 'ensemble learning?',
#  204: 'basic data structures',
#  205: 'Types of machine learning',
#  206: 'Hypothesis Generation',
#  207: 'Data Wrangling',
#  208: 'labeled and unlabeled data',
#  209: 'features and labels',
#  210: 'Noise',
#  211: 'imbalanced datasheet',
#  212: 'Linear Discriminant Analysis',
#  213: 'Gradient Descent',
#  214: 'Regularization',
#  215: 'Regularization in Machine Learning',
#  216: 'Classification model',
#  217: 'issues to consider in supervised learning',
#  218: 'algorithm is used best for supervised learning',
#  219: 'standard supervised learning',
#  220: 'applications of supervised learning',
#  221: 'Support Vector Machine',
#  222: 'advantages of supervised learning',
#  223: 'disadvantages of supervised learning',
#  224: 'Decision Trees',
#  225: 'K-Nearest Neighbor Algorithm',
#  226: 'neural networks algorithms',
#  227: 'algorithms used by neural networks.',
#  228: 'best practices for supervised learning',
#  229: 'self supervised learning',
#  230: 'applications of self-supervised learning',
#  231: 'Polynomial Regression',
#  232: 'using Polynomial Regression',
#  233: 'advantages of using Polynomial Regression over Linear Regression',
#  234: 'Ridge Regression technique',
#  235: 'importance of unsupervised learning',
#  236: 'principle of Unsupervised Data Augmentation',
#  237: 'use of auto encoder',
#  238: 'PCA or auto encoder',
#  239: 'use of unsupervised clustering models',
#  240: 'techniques for anomaly detection on a dataset',
#  241: 'need of unsupervised learning',
#  242: 'unsupervised learning algorithm for categorical data',
#  243: 'types of clustering methods',
#  244: 'Density based lagorithms',
#  245: 'hierarchical clustering based method',
#  246: 'partitioning clustering method',
#  247: 'grid-based clsutering methods',
#  248: 'use of KNN algorithm',
#  249: 'working of knn algorithm',
#  250: 'disadvantages of knn algorithm',
#  251: 'working of k-means algorithm',
#  252: 'advantages of k-means algorithm',
#  253: 'disadvantges of using k-means',
#  254: 'advantages of knn algorithm'}

# %%
label2id
# Out:
# {'greeting': 0,
#  'goodbye': 1,
#  'thanks': 2,
#  'options': 3,
#  'adverse_drug': 4,
#  'blood_pressure': 5,
#  'blood_pressure_search': 6,
#  'pharmacy_search': 7,
#  'hospital_search': 8,
#  'Concern': 9,
#  'Appreciation': 10,
#  'Please': 11,
#  'Criticism': 12,
#  'Personal': 13,
#  'LifeQueries': 14,
#  'diff_classreg': 15,
#  'traintest': 16,
#  'Ensemble': 17,
#  'LowBi_HighVar': 18,
#  'diff_RF_GB': 19,
#  'Neural_Network': 20,
#  'Deep_Learning': 21,
#  'diff_DPDPDW': 22,
#  'building_a_model': 23,
#  'choose_algo': 24,
#  'BiasML': 25,
#  'Variance': 26,
#  'ML_DL': 27,
#  'Prec_Rec': 28,
#  'Para': 29,
#  'SupLearn': 30,
#  'types_SL': 31,
#  'Classification_algo': 32,
#  'ClassDef': 33,
#  'Eg_Class': 34,
#  'Reg': 35,
#  'Reg_Eg': 36,
#  'Class_Tasks': 37,
#  'BinaryClass': 38,
#  'distributionBC': 39,
#  'pop_algo': 40,
#  'MCC': 41,
#  'distrbutionMC': 42,
#  'Pop_algoMC': 43,
#  'MLC': 44,
#  'imbalanced_classification': 45,
#  'use_reg': 46,
#  'types_reg': 47,
#  'func_SL': 48,
#  'standard_approach': 49,
#  'classifier': 50,
#  'SVM': 51,
#  'meth_SVM': 52,
#  'Confusion_Matrix': 53,
#  'Exp_TP_TN_FP_FN': 54,
#  'ml': 55,
#  'difference between Data Mining and Machine learning': 56,
#  'Overfitting': 57,
#  'Why overfitting happens': 58,
#  'avoid overfitting': 59,
#  'inductive machine learning': 60,
#  'algorithms of Machine Learning': 61,
#  'Algorithm techniques in Machine Learning': 62,
#  'algorithm independent machine learning': 63,
#  'difference between artificial learning and machine learning': 64,
#  'classifier in machine learning': 65,
#  'Model Selection in Machine Learning': 66,
#  'various approaches for machine learning': 67,
#  'dimension reduction in machine learning': 68,
#  'Inductive Logic Programming in Machine Learning': 69,
#  'unsupervised learning': 70,
#  'example of unsupervised learning algorithm': 71,
#  'use of unsupervised learning': 72,
#  'types of unsupervised learning': 73,
#  'different types of Learning/ Training models in ML': 74,
#  'differences between supervised and unsupervised machine learning': 75,
#  'differences between KNN and K-means clustering': 76,
#  'unsupervised learning algorithms': 77,
#  'applications of unsupervised machine learning': 78,
#  'disadvantages of unsupervised machine learning': 79,
#  'clustering': 80,
#  'association': 81,
#  'differences between K-Means and Hierarchical clustering': 82,
#  'Hierarchical clustering': 83,
#  'K-Means clustering': 84,
#  'agglomerative clustering': 85,
#  'dendrogram': 86,
#  'K-Nearest Neighbors': 87,
#  'clustering methods': 88,
#  'unsupervised learning work': 89,
#  'need of clustering': 90,
#  'good clustering': 91,
#  'major clustering techniques': 92,
#  'examples of clustering applications': 93,
#  'key difference between supervised and unsupervised learning': 94,
#  'applications': 95,
#  'working of GMaps': 96,
#  'Friend Tag suggestion': 97,
#  'Terms': 98,
#  'ETA Prediction': 99,
#  'Role of machine learning in voice assistants': 100,
#  'Machine Learning in self-driving cars': 101,
#  'Market Analysis': 102,
#  'A/B Testing': 103,
#  'Sampling': 104,
#  'Dimensionality Reduction': 105,
#  'Realtional Evaluation': 106,
#  'Areas of Problems': 107,
#  'PAC Learning': 108,
#  'Sequence Learning process': 109,
#  'gf_sp': 110,
#  'gf_sp_again': 111,
#  'creation_sp': 112,
#  'ava_sp': 113,
#  'smart_sp': 114,
#  'evil_sp': 115,
#  'hurt_sp': 116,
#  'obey_sp': 117,
#  'save_yourself_sp': 118,
#  'sanjoy_sp': 119,
#  'sing_happy_birthday_sp': 120,
#  'sing_song_sp': 121,
#  'book_sp': 122,
#  'mark_sp': 123,
#  'gandhi_sp': 124,
#  'country_sp': 125,
#  'human_sp': 126,
#  'love_sp': 127,
#  'will_love_sp': 128,
#  'past_sp': 129,
#  'sad_sp': 130,
#  'fail_sp': 131,
#  'kernel SVM': 132,
#  'Recommended Systems': 133,
#  'Overfitting in laymen term': 134,
#  'Underfitting in laymen term': 135,
#  'Curse of dimensionality': 136,
#  'data normalization': 137,
#  'clustering in short': 138,
#  'EDA': 139,
#  'avoid Bias': 140,
#  'Z Score': 141,
#  'odds ratio': 142,
#  'classification problems': 143,
#  'trade-off between accuracy and interpretability': 144,
#  'missing data': 145,
#  'gradient descent methods converge': 146,
#  'methods of moments': 147,
#  'Face Clustering Pipeline': 148,
#  'working of unsupervised face clustering pipeline': 149,
#  'python3 modules to implement unsupervised face clustering pipeline': 150,
#  'face clustering and its realtion  unsupervised learning': 151,
#  'exclusive clustering': 152,
#  'overlapping clustering': 153,
#  'probabilistic clustering': 154,
#  'Fzzy c-Means': 155,
#  'FCM algorithm': 156,
#  'comparison between K-Means and FCM clustering': 157,
#  'applications of association rules': 158,
#  'terms related to association rules': 159,
#  'algorithms for association rule generation': 160,
#  'FP growth algorithm': 161,
#  'FP tree structure by Han': 162,
#  'algorithm for building a fp tree': 163,
#  'algorithm for mining a fp tree': 164,
#  'Apriori algorithm': 165,
#  'working of apriori algorithm': 166,
#  'limitations of apriori algorithm': 167,
#  'ECLAT algorithm': 168,
#  'working of eclat algorithm': 169,
#  'advanatges of eclat algorithm': 170,
#  'detection of fake users using unsupervised learning': 171,
#  'reinforcement learning': 172,
#  'relation between reinforcement learning and machine learning': 173,
#  'key terms realted to reinforcement learning': 174,
#  'formulation of a reinforcement problem': 175,
#  'reinforcement learning algorithms': 176,
#  'applications of reinforcement learning': 177,
#  'resources to learn reinforcement learning': 178,
#  'types of reinforcement learning': 179,
#  'advantages and disadvanatages of reinforcement learning': 180,
#  'why rl is hard': 181,
#  'solution of cartpole problem': 182,
#  "'action' in reinforcement learning": 183,
#  "'agent' in reinforcement learning": 184,
#  "'value' in reinforcement learning": 185,
#  'q-value or action-value': 186,
#  'value-based learning': 187,
#  'policy-based reinforcement learning': 188,
#  'model-based learning': 189,
#  'PATTERN RECOGNITION': 190,
#  'genetic programming': 191,
#  'Inductive Logic Programming': 192,
#  'model selection': 193,
#  'calibration in Supervised Learning': 194,
#  'overfitting': 195,
#  'difference between heuristic for rule learning and heuristics': 196,
#  'Perceptron': 197,
#  'components of Bayesian logic program': 198,
#  'bayesian networks': 199,
#  'Lazy learning algorithm': 200,
#  'Support Vector Machine': 221,
#  'cross-validation?': 202,
#  'ensemble learning?': 203,
#  'basic data structures': 204,
#  'Types of machine learning': 205,
#  'Hypothesis Generation': 206,
#  'Data Wrangling': 207,
#  'labeled and unlabeled data': 208,
#  'features and labels': 209,
#  'Noise': 210,
#  'imbalanced datasheet': 211,
#  'Linear Discriminant Analysis': 212,
#  'Gradient Descent': 213,
#  'Regularization': 214,
#  'Regularization in Machine Learning': 215,
#  'Classification model': 216,
#  'issues to consider in supervised learning': 217,
#  'algorithm is used best for supervised learning': 218,
#  'standard supervised learning': 219,
#  'applications of supervised learning': 220,
#  'advantages of supervised learning': 222,
#  'disadvantages of supervised learning': 223,
#  'Decision Trees': 224,
#  'K-Nearest Neighbor Algorithm': 225,
#  'neural networks algorithms': 226,
#  'algorithms used by neural networks.': 227,
#  'best practices for supervised learning': 228,
#  'self supervised learning': 229,
#  'applications of self-supervised learning': 230,
#  'Polynomial Regression': 231,
#  'using Polynomial Regression': 232,
#  'advantages of using Polynomial Regression over Linear Regression': 233,
#  'Ridge Regression technique': 234,
#  'importance of unsupervised learning': 235,
#  'principle of Unsupervised Data Augmentation': 236,
#  'use of auto encoder': 237,
#  'PCA or auto encoder': 238,
#  'use of unsupervised clustering models': 239,
#  'techniques for anomaly detection on a dataset': 240,
#  'need of unsupervised learning': 241,
#  'unsupervised learning algorithm for categorical data': 242,
#  'types of clustering methods': 243,
#  'Density based lagorithms': 244,
#  'hierarchical clustering based method': 245,
#  'partitioning clustering method': 246,
#  'grid-based clsutering methods': 247,
#  'use of KNN algorithm': 248,
#  'working of knn algorithm': 249,
#  'disadvantages of knn algorithm': 250,
#  'working of k-means algorithm': 251,
#  'advantages of k-means algorithm': 252,
#  'disadvantges of using k-means': 253,
#  'advantages of knn algorithm': 254}

# %%
df_2['labels'] = df_2['Tag'].map(lambda x : label2id[x.strip()])
df_2.head()
# Out:
#             Pattern       Tag  labels
# 0          Hi there  greeting       0
# 1       How are you  greeting       0
# 2  Is anyone there?  greeting       0
# 3               Hey  greeting       0
# 4              Hola  greeting       0

# %%
#Splitting of data into train and test data
X = list(df_2['Pattern'])
X[:5]
# Out:
# ['Hi there', 'How are you', 'Is anyone there?', 'Hey', 'Hola']

# %%
y= list(df_2['labels'])
y[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=123)

# %%
#Loading BERT pretrained model and Tokenizer
model_name = "bert-base-uncased"
max_len = 256

tokenizer = BertTokenizer.from_pretrained(model_name,max_length=max_len)

model = BertForSequenceClassification.from_pretrained(model_name,num_labels=num_labels,
                                                      id2label=id2label, label2id=label2id)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#Encoding 
train_encoding = tokenizer(X_train,truncation=True,padding=True)
test_encoding = tokenizer(X_test,truncation=True,padding=True)

# %%
full_data = tokenizer(X,truncation=True,padding=True)

# %%
#Building Data loader
class DataLoader(Dataset):
    def __init__(self,encodings,labels):

        self.encodings = encodings
        self.labels = labels

    def __getitem__(self,idx):

        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_dataloader = DataLoader(train_encoding,y_train)
test_dataloader = DataLoader(test_encoding,y_test)

# %%
fullDataLoader = DataLoader(full_data,y_test)

# %%
#Defining evaluation metrics
def evaluation_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision,recall,f1,_ = precision_recall_fscore_support(labels,preds,average='macro')
    acc= accuracy_score(labels,preds)
    return{
        'Accuracy': acc,
        'F1': f1,
        'Precision': precision,
        'Recall': recall
    }

# %%
#defining Training arguments

training_args = TrainingArguments(
    output_dir = './output',
    do_train = True,
    do_eval = True,
    num_train_epochs=100,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=16,
    warmup_steps = 100,
    weight_decay=0.05,
    logging_strategy='steps',
    logging_dir='./multi-class-logs',
    logging_steps=50,
    eval_strategy="steps",
    eval_steps=50,
    save_strategy="steps",
    load_best_model_at_end=True
    
)

# %%
trainer = Trainer(
    model= model,
    args=training_args,
    train_dataset=train_dataloader,
    eval_dataset=test_dataloader,
    compute_metrics=evaluation_metrics
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2200' max='2200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2200/2200 7:46:51, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>5.545100</td>
#       <td>5.545964</td>
#       <td>0.008772</td>
#       <td>0.001902</td>
#       <td>0.001076</td>
#       <td>0.009615</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>5.311400</td>
#       <td>5.302005</td>
#       <td>0.043860</td>
#       <td>0.014996</td>
#       <td>0.016522</td>
#       <td>0.032292</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>4.793800</td>
#       <td>4.846290</td>
#       <td>0.127193</td>
#       <td>0.091764</td>
#       <td>0.094715</td>
#       <td>0.106105</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>4.125300</td>
#       <td>4.395943</td>
#       <td>0.267544</td>
#       <td>0.174897</td>
#       <td>0.161564</td>
#       <td>0.217228</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>3.484000</td>
#       <td>3.969693</td>
#       <td>0.377193</td>
#       <td>0.276203</td>
#       <td>0.270090</td>
#       <td>0.315315</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.937900</td>
#       <td>3.616684</td>
#       <td>0.447368</td>
#       <td>0.333717</td>
#       <td>0.324503</td>
#       <td>0.375000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>2.462800</td>
#       <td>3.274916</td>
#       <td>0.526316</td>
#       <td>0.421161</td>
#       <td>0.421910</td>
#       <td>0.461142</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>2.014900</td>
#       <td>2.978503</td>
#       <td>0.583333</td>
#       <td>0.490820</td>
#       <td>0.491811</td>
#       <td>0.524566</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.650500</td>
#       <td>2.719600</td>
#       <td>0.622807</td>
#       <td>0.505374</td>
#       <td>0.505493</td>
#       <td>0.536313</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.379500</td>
#       <td>2.486038</td>
#       <td>0.649123</td>
#       <td>0.545752</td>
#       <td>0.549621</td>
#       <td>0.573864</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.118600</td>
#       <td>2.258062</td>
#       <td>0.666667</td>
#       <td>0.573601</td>
#       <td>0.576413</td>
#       <td>0.605263</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.882400</td>
#       <td>2.065621</td>
#       <td>0.671053</td>
#       <td>0.579205</td>
#       <td>0.580276</td>
#       <td>0.612426</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.707900</td>
#       <td>1.883023</td>
#       <td>0.714912</td>
#       <td>0.646801</td>
#       <td>0.658896</td>
#       <td>0.673313</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.569500</td>
#       <td>1.745881</td>
#       <td>0.706140</td>
#       <td>0.645179</td>
#       <td>0.654733</td>
#       <td>0.674383</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.452200</td>
#       <td>1.636572</td>
#       <td>0.741228</td>
#       <td>0.668467</td>
#       <td>0.677744</td>
#       <td>0.693598</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.371000</td>
#       <td>1.501138</td>
#       <td>0.741228</td>
#       <td>0.675431</td>
#       <td>0.693661</td>
#       <td>0.696830</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.300500</td>
#       <td>1.404947</td>
#       <td>0.767544</td>
#       <td>0.704525</td>
#       <td>0.718841</td>
#       <td>0.727226</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.236700</td>
#       <td>1.316617</td>
#       <td>0.785088</td>
#       <td>0.725337</td>
#       <td>0.733124</td>
#       <td>0.752096</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.195800</td>
#       <td>1.262757</td>
#       <td>0.785088</td>
#       <td>0.720725</td>
#       <td>0.726834</td>
#       <td>0.747379</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.162800</td>
#       <td>1.217313</td>
#       <td>0.789474</td>
#       <td>0.723750</td>
#       <td>0.733437</td>
#       <td>0.743271</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.131700</td>
#       <td>1.187745</td>
#       <td>0.793860</td>
#       <td>0.732704</td>
#       <td>0.740881</td>
#       <td>0.756813</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.118700</td>
#       <td>1.168124</td>
#       <td>0.793860</td>
#       <td>0.733723</td>
#       <td>0.741509</td>
#       <td>0.756813</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.100200</td>
#       <td>1.143846</td>
#       <td>0.789474</td>
#       <td>0.727878</td>
#       <td>0.732911</td>
#       <td>0.755274</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.092500</td>
#       <td>1.135718</td>
#       <td>0.785088</td>
#       <td>0.721324</td>
#       <td>0.729036</td>
#       <td>0.746331</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.082900</td>
#       <td>1.128622</td>
#       <td>0.793860</td>
#       <td>0.737945</td>
#       <td>0.747257</td>
#       <td>0.760549</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.076100</td>
#       <td>1.118732</td>
#       <td>0.789474</td>
#       <td>0.721458</td>
#       <td>0.728958</td>
#       <td>0.745833</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.067600</td>
#       <td>1.111052</td>
#       <td>0.798246</td>
#       <td>0.728721</td>
#       <td>0.733543</td>
#       <td>0.754717</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.064500</td>
#       <td>1.108331</td>
#       <td>0.798246</td>
#       <td>0.737312</td>
#       <td>0.743038</td>
#       <td>0.762658</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.060200</td>
#       <td>1.111708</td>
#       <td>0.793860</td>
#       <td>0.728482</td>
#       <td>0.734172</td>
#       <td>0.752621</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.058700</td>
#       <td>1.102478</td>
#       <td>0.789474</td>
#       <td>0.725996</td>
#       <td>0.732075</td>
#       <td>0.750524</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.054600</td>
#       <td>1.106571</td>
#       <td>0.798246</td>
#       <td>0.729140</td>
#       <td>0.733543</td>
#       <td>0.754717</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.053800</td>
#       <td>1.102009</td>
#       <td>0.802632</td>
#       <td>0.734771</td>
#       <td>0.739413</td>
#       <td>0.756813</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.051000</td>
#       <td>1.101333</td>
#       <td>0.798246</td>
#       <td>0.735274</td>
#       <td>0.737580</td>
#       <td>0.764331</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.048100</td>
#       <td>1.100467</td>
#       <td>0.798246</td>
#       <td>0.735274</td>
#       <td>0.737580</td>
#       <td>0.764331</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.047300</td>
#       <td>1.102233</td>
#       <td>0.802632</td>
#       <td>0.735010</td>
#       <td>0.739832</td>
#       <td>0.761006</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.044500</td>
#       <td>1.098731</td>
#       <td>0.802632</td>
#       <td>0.735010</td>
#       <td>0.739832</td>
#       <td>0.761006</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.044000</td>
#       <td>1.093856</td>
#       <td>0.802632</td>
#       <td>0.735430</td>
#       <td>0.739832</td>
#       <td>0.761006</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.043600</td>
#       <td>1.096326</td>
#       <td>0.802632</td>
#       <td>0.735010</td>
#       <td>0.739832</td>
#       <td>0.761006</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.042700</td>
#       <td>1.099838</td>
#       <td>0.802632</td>
#       <td>0.735010</td>
#       <td>0.739832</td>
#       <td>0.761006</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.041900</td>
#       <td>1.099361</td>
#       <td>0.802632</td>
#       <td>0.735010</td>
#       <td>0.739832</td>
#       <td>0.761006</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.040200</td>
#       <td>1.097798</td>
#       <td>0.802632</td>
#       <td>0.739060</td>
#       <td>0.742405</td>
#       <td>0.765823</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.041500</td>
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Could not locate the best model at ./output\checkpoint-1850\pytorch_model.bin, if you are running a distributed training on multiple nodes, you should activate `--save_on_each_node`.
# TrainOutput(global_step=2200, training_loss=0.9133891406384381, metrics={'train_runtime': 28014.5968, 'train_samples_per_second': 2.434, 'train_steps_per_second': 0.079, 'total_flos': 913297515530400.0, 'train_loss': 0.9133891406384381, 'epoch': 100.0})

# %%
q = [trainer.evaluate(eval_dataset=df_2) for df_2 in [train_dataloader,test_dataloader]]

pd.DataFrame(q,index=['train','test']).iloc[:,:5]
# Out:
#     <div>
#
#       <progress value='58' max='43' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [43/43 00:25]
#     </div>
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\abhin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#        eval_loss  eval_Accuracy   eval_F1  eval_Precision  eval_Recall
# train   0.028882       0.995601  0.988895        0.988911     0.990040
# test    1.098579       0.802632  0.739060        0.742405     0.765823

# %%
def predict(text):
    inputs = tokenizer(text,padding=True,truncation=True,max_length=512 , 
                       return_tensors="pt").to("cpu")
    outputs = model(**inputs)

    probs= outputs[0].softmax(1)
    pred_label_idx = probs.argmax()
    pred_label = model.config.id2label[pred_label_idx.item()]

    return probs, pred_label_idx , pred_label

# %%
text="Hello"
predict(text)
# Out:
# (tensor([[9.8681e-01, 2.9328e-04, 3.2687e-04, 2.7762e-04, 1.1847e-05, 5.1404e-05,
#           1.7475e-04, 1.8657e-05, 2.8611e-04, 1.0343e-03, 1.8958e-05, 7.0986e-05,
#           1.1048e-04, 1.5571e-05, 2.9354e-04, 5.9393e-06, 1.6311e-05, 1.9565e-04,
#           6.7638e-06, 8.6795e-06, 1.9899e-05, 1.7083e-05, 1.5972e-04, 3.2423e-05,
#           6.9710e-05, 1.6556e-05, 1.3333e-05, 4.4157e-05, 1.0653e-05, 1.0231e-05,
#           1.5768e-05, 5.0025e-05, 1.8968e-05, 8.5064e-05, 6.9974e-06, 3.4579e-05,
#           1.3876e-05, 6.6663e-06, 1.2365e-05, 1.0885e-05, 1.4199e-05, 1.1467e-05,
#           2.2088e-05, 1.9296e-06, 4.6197e-06, 1.7411e-05, 2.6737e-06, 5.0778e-06,
#           2.6379e-06, 2.3107e-06, 4.0091e-05, 3.6404e-05, 2.2221e-06, 4.1355e-05,
#           1.4981e-04, 4.0377e-05, 9.8787e-05, 2.7089e-05, 1.5880e-04, 3.4511e-05,
#           1.2422e-05, 1.3068e-04, 3.7702e-05, 1.6277e-04, 1.1259e-05, 6.8784e-05,
#           1.0352e-04, 1.6375e-05, 4.6631e-05, 1.6654e-04, 3.0020e-05, 6.2461e-06,
#           5.6123e-06, 9.7398e-05, 2.6899e-06, 8.0263e-06, 2.3152e-05, 6.7515e-06,
#           5.5302e-05, 1.1825e-05, 1.7687e-05, 1.1114e-05, 1.0662e-04, 5.5213e-06,
#           3.0561e-05, 1.1924e-06, 2.4706e-05, 4.1252e-05, 1.6594e-05, 1.8782e-05,
#           7.6136e-06, 1.9659e-05, 6.5033e-06, 1.0434e-04, 3.2840e-05, 3.6939e-05,
#           4.1833e-05, 2.0559e-05, 5.0448e-05, 5.3764e-05, 5.7276e-06, 3.1152e-05,
#           3.5332e-05, 4.5429e-06, 9.0540e-06, 4.1859e-06, 1.7540e-06, 3.1108e-05,
#           2.0381e-05, 5.6052e-05, 5.0501e-06, 7.3647e-06, 1.0132e-04, 6.1272e-04,
#           7.5311e-05, 1.2473e-03, 1.0103e-05, 6.5909e-06, 1.3655e-04, 3.3520e-06,
#           2.5210e-05, 2.1941e-05, 3.1978e-05, 6.7232e-05, 1.2861e-05, 1.8901e-04,
#           7.5258e-05, 2.4799e-05, 2.0751e-05, 1.3492e-04, 5.3038e-06, 6.2181e-06,
#           3.2940e-05, 3.5562e-06, 2.5289e-04, 7.5030e-05, 3.7491e-04, 1.3402e-05,
#           7.7105e-06, 1.2321e-05, 2.2354e-05, 3.7759e-05, 2.4618e-05, 2.2691e-04,
#           1.4276e-05, 8.1608e-05, 2.0246e-05, 3.4233e-05, 7.3934e-06, 9.2149e-06,
#           1.7449e-05, 4.6033e-05, 1.0533e-05, 7.7735e-06, 1.0464e-05, 6.6898e-06,
#           2.6238e-05, 3.1469e-06, 6.3882e-06, 5.8116e-06, 4.9458e-06, 4.0245e-05,
#           1.6560e-05, 3.8989e-06, 1.3769e-05, 5.8774e-06, 1.5435e-05, 7.1208e-06,
#           1.9612e-05, 5.6926e-05, 1.3119e-05, 3.4324e-06, 2.7962e-05, 2.3820e-05,
#           2.6251e-05, 9.2288e-06, 4.4414e-06, 2.2881e-06, 1.4615e-05, 4.1858e-06,
#           8.6556e-07, 5.0845e-06, 3.1315e-06, 8.5791e-06, 3.5849e-05, 4.2756e-06,
#           7.0756e-06, 2.5721e-06, 8.2286e-06, 1.0097e-05, 3.5834e-05, 2.9007e-05,
#           5.2757e-06, 2.9708e-05, 1.8097e-05, 2.8028e-05, 8.0794e-06, 8.5289e-05,
#           6.6107e-06, 6.5853e-06, 6.8470e-05, 1.8876e-05, 1.6703e-06, 3.4967e-05,
#           4.2664e-05, 7.7145e-05, 1.6079e-04, 3.8401e-05, 1.9050e-04, 2.7455e-05,
#           9.5319e-05, 1.8135e-05, 1.6604e-05, 6.8837e-05, 3.3292e-06, 1.9927e-05,
#           7.1129e-05, 2.2763e-06, 6.7570e-06, 5.3716e-05, 2.9861e-06, 1.1935e-06,
#           4.3009e-06, 2.2741e-05, 7.2407e-06, 1.5008e-05, 1.7219e-05, 6.9261e-06,
#           5.1209e-06, 6.0707e-05, 5.4697e-07, 1.2932e-05, 3.8168e-06, 4.5680e-06,
#           1.8287e-06, 5.8022e-06, 4.9403e-06, 2.0428e-06, 1.5433e-06, 2.1654e-04,
#           1.5649e-04, 1.1662e-05, 4.7134e-05, 2.0327e-05, 2.4131e-06, 1.3333e-05,
#           2.3953e-05, 2.8251e-05, 6.9396e-06, 4.4560e-05, 2.9886e-06, 8.8747e-05,
#           5.1238e-06, 2.6663e-05, 3.9816e-07]], grad_fn=<SoftmaxBackward0>),
#  tensor(0),
#  'greeting')

# %%
#Save the model 
model_path = "chatbot"
trainer.save_model(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('chatbot\\tokenizer_config.json',
#  'chatbot\\special_tokens_map.json',
#  'chatbot\\vocab.txt',
#  'chatbot\\added_tokens.json')

# %%
#Load the model
model_path = "chatbot"

model = BertForSequenceClassification.from_pretrained(model_path)
tokenizer = BertTokenizerFast.from_pretrained(model_path)
chatbot = pipeline("sentiment-analysis", model=model , tokenizer=tokenizer)
# Out:
# Device set to use cpu

# %%
chatbot("Hello")
# Out:
# [{'label': 'greeting', 'score': 0.9868088960647583}]

# %%
#chat with the chatbot

def chat(chatbot):
    print("Chatbot: Hi! I am your virtual assistance, Feel free to ask, and I'll do my best to provide you with answers and assistance..")
    print("Type 'quit' to exit the chat\n\n")

    text=input("User: ").strip().lower()
    while(text != 'quit'):
        score = chatbot(text)[0]['score']
        if score <0.8:
            print("Chatbot: Sorry I can't answer that\n\n")
            text= input("User: ").strip().lower()
            continue
        label = label2id[chatbot(text)[0]['label']]
        response = random.choice(intents['intents'][label]['responses'])
        print(f"Chatbot: {response}\n\n")
        text = input("User: ").strip().lower()

# %%
chat(chatbot)
# Out:
# Chatbot: Hi! I am your virtual assistance, Feel free to ask, and I'll do my best to provide you with answers and assistance..
# Type 'quit' to exit the chat
# User:  hiii
# Chatbot: Sorry I can't answer that
# User:  What are you doing
# Chatbot: Please provide hospital type
# User:  Do you like someone
# Chatbot: Loading hospital details
# User:  do u like partho
# Chatbot: Sorry I can't answer that
